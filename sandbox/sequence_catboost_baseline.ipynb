# %% [markdown]
# ### Import libraries

# %%
import warnings

import numpy as np
import pandas as pd
import random

import torch
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %%
import sys
import os
import gc
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ["USE_OPENMP"] = '1'

sys.path.append(os.path.abspath("../"))
from fe_modules.aggregates import get_agg_count, get_agg_sum, get_top_n_mode, \
                                  get_agg_mean, get_agg_max, get_agg_min, \
                                  get_agg_median, get_agg_std, get_agg_nunique, \
                                  get_price_of_all_cpes, get_ratio_part_of_day
from fe_modules.cyclical_features import generate_cyclical_features
from fe_modules.datetime_features import get_year, get_month, get_day, \
                                         get_timestamp, get_day_of_year, \
                                         get_day_of_week, get_holiday_name, \
                                         part_of_day_to_hour, add_hour_to_date, \
                                         get_relative_time, mean_first_visit, \
                                         mean_last_visit
from fe_modules.encoders import TargetEncoderWrapper
from fe_modules.feature_merges import add_cat_features
from fe_modules.geo_features import map_cities, geo_dist, dist_to_large_cities, \
                                    map_grid, MapGridTransformer
from fe_modules.missing import map_prices
from fe_modules.preprocessing import clean_os_type
from fe_modules.text_manipulation import get_domain
from fe_modules.time_lags import generate_time_lags
from fe_modules.recsys_features import ALSWrapper, RecVAEWrapper

from fe_modules.user_fe import UserFE

from modules.memory_utils import pandas_reduce_mem_usage

from seq2seq_modules.metrics import GENDER_METRIC
from fe_modules.encoders import CatBoostEncoderWrapper

# %%
def my_reset(*varnames):
    """
    varnames are what you want to keep
    """
    globals_ = globals()
    to_save = {v: globals_[v] for v in varnames}
    to_save['my_reset'] = my_reset  # lets keep this function by default
    del globals_
    get_ipython().magic("reset")
    globals().update(to_save)

# %%
random_state = 69

random.seed(random_state),
np.random.seed(random_state)
torch.manual_seed(random_state)
torch.cuda.manual_seed_all(random_state)

# %% [markdown]
# ### Read Data

# %%
LOCAL_DATA = "../data"

# %%
df = pandas_reduce_mem_usage( 
        pd.read_parquet(f'{LOCAL_DATA}/competition_data_final_pqt')
)

targets = pandas_reduce_mem_usage( 
        pd.read_parquet(f'{LOCAL_DATA}/public_train.pqt')
) 

df = df.merge(targets, how="left", on="user_id")

df.head()
# Out:
# Memory usage of dataframe is 29562.33 MB
#   0%|          | 0/12 [00:00<?, ?it/s]
# Memory usage after optimization is: 26174.98 MB
# Decreased by 11.5%
# Memory usage of dataframe is 8.24 MB
#   0%|          | 0/3 [00:00<?, ?it/s]
# Memory usage after optimization is: 7.21 MB
# Decreased by 12.5%
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  request_cnt  user_id  age is_male
# 0  2022-06-15     morning            1    45098  NaN     NaN
# 1  2022-06-19     morning            1    45098  NaN     NaN
# 2  2022-06-12         day            1    45098  NaN     NaN
# 3  2022-05-16         day            1    45098  NaN     NaN
# 4  2022-05-30         day            1    45098  NaN     NaN

# %%
df["is_male"] = df["is_male"].fillna(value=np.nan)
df.loc[df["is_male"] == "NA", "is_male"] = np.nan
df["is_male"] = df["is_male"].astype(np.float32)
df
# Out:
#                   region_name  city_name cpe_manufacturer_name  \
# 0          Краснодарский край  Краснодар                 Apple
# 1          Краснодарский край  Краснодар                 Apple
# 2          Краснодарский край  Краснодар                 Apple
# 3          Краснодарский край  Краснодар                 Apple
# 4          Краснодарский край  Краснодар                 Apple
# ...                       ...        ...                   ...
# 322899430   Калужская область    Обнинск               Samsung
# 322899431   Калужская область    Обнинск               Samsung
# 322899432   Калужская область    Обнинск               Samsung
# 322899433   Калужская область    Обнинск               Samsung
# 322899434   Калужская область    Обнинск               Samsung
#
#              cpe_model_name                     url_host cpe_type_cd  \
# 0                  iPhone 7                ad.adriver.ru  smartphone
# 1                  iPhone 7                    apple.com  smartphone
# 2                  iPhone 7       avatars.mds.yandex.net  smartphone
# 3                  iPhone 7  googleads.g.doubleclick.net  smartphone
# 4                  iPhone 7  googleads.g.doubleclick.net  smartphone
# ...                     ...                          ...         ...
# 322899430  Galaxy A30s Dual       avatars.mds.yandex.net  smartphone
# 322899431  Galaxy A30s Dual  googleads.g.doubleclick.net  smartphone
# 322899432  Galaxy A30s Dual           online.sberbank.ru  smartphone
# 322899433  Galaxy A30s Dual                  s0.2mdn.net  smartphone
# 322899434  Galaxy A30s Dual                zen.yandex.ru  smartphone
#
#           cpe_model_os_type    price        date part_of_day  request_cnt  \
# 0                       iOS  20368.0  2022-06-15     morning            1
# 1                       iOS  20368.0  2022-06-19     morning            1
# 2                       iOS  20368.0  2022-06-12         day            1
# 3                       iOS  20368.0  2022-05-16         day            1
# 4                       iOS  20368.0  2022-05-30         day            1
# ...                     ...      ...         ...         ...          ...
# 322899430           Android  16376.0  2021-07-12     morning            1
# 322899431           Android  16376.0  2021-06-20     evening            1
# 322899432           Android  16376.0  2021-08-05         day            1
# 322899433           Android  16376.0  2021-07-19     evening            1
# 322899434           Android  16376.0  2021-08-09       night            1
#
#            user_id   age  is_male
# 0            45098   NaN      NaN
# 1            45098   NaN      NaN
# 2            45098   NaN      NaN
# 3            45098   NaN      NaN
# 4            45098   NaN      NaN
# ...            ...   ...      ...
# 322899430   300964  57.0      0.0
# 322899431   300964  57.0      0.0
# 322899432   300964  57.0      0.0
# 322899433   300964  57.0      0.0
# 322899434   300964  57.0      0.0
#
# [322899435 rows x 14 columns]

# %%
df = clean_os_type(df)
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  request_cnt  user_id  age  is_male
# 0  2022-06-15     morning            1    45098  NaN      NaN
# 1  2022-06-19     morning            1    45098  NaN      NaN
# 2  2022-06-12         day            1    45098  NaN      NaN
# 3  2022-05-16         day            1    45098  NaN      NaN
# 4  2022-05-30         day            1    45098  NaN      NaN

# %%
df = get_year(df)
df = get_month(df)
df = get_day(df)
df = pandas_reduce_mem_usage(df)
df.head()
# Out:
# Memory usage of dataframe is 39724.38 MB
#   0%|          | 0/17 [00:00<?, ?it/s]
# Memory usage after optimization is: 33565.56 MB
# Decreased by 15.5%
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  request_cnt  user_id  age  is_male  year  month  \
# 0  2022-06-15     morning            1    45098  NaN      NaN  2022      6
# 1  2022-06-19     morning            1    45098  NaN      NaN  2022      6
# 2  2022-06-12         day            1    45098  NaN      NaN  2022      6
# 3  2022-05-16         day            1    45098  NaN      NaN  2022      5
# 4  2022-05-30         day            1    45098  NaN      NaN  2022      5
#
#    day
# 0   15
# 1   19
# 2   12
# 3   16
# 4   30

# %%
df = get_day_of_year(df)
df = get_day_of_week(df)
df = pandas_reduce_mem_usage(df)
df.head()
# Out:
# Memory usage of dataframe is 38492.61 MB
#   0%|          | 0/19 [00:00<?, ?it/s]
# Memory usage after optimization is: 34489.38 MB
# Decreased by 10.4%
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  request_cnt  user_id  age  is_male  year  month  \
# 0  2022-06-15     morning            1    45098  NaN      NaN  2022      6
# 1  2022-06-19     morning            1    45098  NaN      NaN  2022      6
# 2  2022-06-12         day            1    45098  NaN      NaN  2022      6
# 3  2022-05-16         day            1    45098  NaN      NaN  2022      5
# 4  2022-05-30         day            1    45098  NaN      NaN  2022      5
#
#    day  day_of_year  day_of_week
# 0   15          166            2
# 1   19          170            6
# 2   12          163            6
# 3   16          136            0
# 4   30          150            0

# %%
df = get_holiday_name(df)
df = pandas_reduce_mem_usage(df)
df.head()
# Out:
# Memory usage of dataframe is 36952.91 MB
#   0%|          | 0/20 [00:00<?, ?it/s]
# Memory usage after optimization is: 36952.91 MB
# Decreased by 0.0%
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  request_cnt  user_id  age  is_male  year  month  \
# 0  2022-06-15     morning            1    45098  NaN      NaN  2022      6
# 1  2022-06-19     morning            1    45098  NaN      NaN  2022      6
# 2  2022-06-12         day            1    45098  NaN      NaN  2022      6
# 3  2022-05-16         day            1    45098  NaN      NaN  2022      5
# 4  2022-05-30         day            1    45098  NaN      NaN  2022      5
#
#    day  day_of_year  day_of_week      holiday
# 0   15          166            2  Не праздник
# 1   19          170            6  Не праздник
# 2   12          163            6  День России
# 3   16          136            0  Не праздник
# 4   30          150            0  Не праздник

# %%
df = part_of_day_to_hour(df)
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#          date part_of_day  ...  user_id  age  is_male  year  month  day  \
# 0  2022-06-15     morning  ...    45098  NaN      NaN  2022      6   15
# 1  2022-06-19     morning  ...    45098  NaN      NaN  2022      6   19
# 2  2022-06-12         day  ...    45098  NaN      NaN  2022      6   12
# 3  2022-05-16         day  ...    45098  NaN      NaN  2022      5   16
# 4  2022-05-30         day  ...    45098  NaN      NaN  2022      5   30
#
#    day_of_year  day_of_week      holiday            hour
# 0          166            2  Не праздник 0 days 09:00:00
# 1          170            6  Не праздник 0 days 09:00:00
# 2          163            6  День России 0 days 15:00:00
# 3          136            0  Не праздник 0 days 15:00:00
# 4          150            0  Не праздник 0 days 15:00:00
#
# [5 rows x 21 columns]

# %%
df = add_hour_to_date(df)
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#         date part_of_day  ...  age  is_male  year  month  day  day_of_year  \
# 0 2022-06-15     morning  ...  NaN      NaN  2022      6   15          166
# 1 2022-06-19     morning  ...  NaN      NaN  2022      6   19          170
# 2 2022-06-12         day  ...  NaN      NaN  2022      6   12          163
# 3 2022-05-16         day  ...  NaN      NaN  2022      5   16          136
# 4 2022-05-30         day  ...  NaN      NaN  2022      5   30          150
#
#    day_of_week      holiday            hour            datetime
# 0            2  Не праздник 0 days 09:00:00 2022-06-15 09:00:00
# 1            6  Не праздник 0 days 09:00:00 2022-06-19 09:00:00
# 2            6  День России 0 days 15:00:00 2022-06-12 15:00:00
# 3            0  Не праздник 0 days 15:00:00 2022-05-16 15:00:00
# 4            0  Не праздник 0 days 15:00:00 2022-05-30 15:00:00
#
# [5 rows x 22 columns]

# %%
df = df.drop(labels=["date", "hour"], axis=1)
gc.collect()
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#   part_of_day  request_cnt  user_id  age  is_male  year  month  day  \
# 0     morning            1    45098  NaN      NaN  2022      6   15
# 1     morning            1    45098  NaN      NaN  2022      6   19
# 2         day            1    45098  NaN      NaN  2022      6   12
# 3         day            1    45098  NaN      NaN  2022      5   16
# 4         day            1    45098  NaN      NaN  2022      5   30
#
#    day_of_year  day_of_week      holiday            datetime
# 0          166            2  Не праздник 2022-06-15 09:00:00
# 1          170            6  Не праздник 2022-06-19 09:00:00
# 2          163            6  День России 2022-06-12 15:00:00
# 3          136            0  Не праздник 2022-05-16 15:00:00
# 4          150            0  Не праздник 2022-05-30 15:00:00

# %%
df = pandas_reduce_mem_usage(get_timestamp(df), columns=["timestamp"])
df
# Out:
# Memory usage of dataframe is 39416.43 MB
#   0%|          | 0/1 [00:00<?, ?it/s]
# Memory usage after optimization is: 39416.43 MB
# Decreased by 0.0%
#                   region_name  city_name cpe_manufacturer_name  \
# 0          Краснодарский край  Краснодар                 Apple
# 1          Краснодарский край  Краснодар                 Apple
# 2          Краснодарский край  Краснодар                 Apple
# 3          Краснодарский край  Краснодар                 Apple
# 4          Краснодарский край  Краснодар                 Apple
# ...                       ...        ...                   ...
# 322899430   Калужская область    Обнинск               Samsung
# 322899431   Калужская область    Обнинск               Samsung
# 322899432   Калужская область    Обнинск               Samsung
# 322899433   Калужская область    Обнинск               Samsung
# 322899434   Калужская область    Обнинск               Samsung
#
#              cpe_model_name                     url_host cpe_type_cd  \
# 0                  iPhone 7                ad.adriver.ru  smartphone
# 1                  iPhone 7                    apple.com  smartphone
# 2                  iPhone 7       avatars.mds.yandex.net  smartphone
# 3                  iPhone 7  googleads.g.doubleclick.net  smartphone
# 4                  iPhone 7  googleads.g.doubleclick.net  smartphone
# ...                     ...                          ...         ...
# 322899430  Galaxy A30s Dual       avatars.mds.yandex.net  smartphone
# 322899431  Galaxy A30s Dual  googleads.g.doubleclick.net  smartphone
# 322899432  Galaxy A30s Dual           online.sberbank.ru  smartphone
# 322899433  Galaxy A30s Dual                  s0.2mdn.net  smartphone
# 322899434  Galaxy A30s Dual                zen.yandex.ru  smartphone
#
#           cpe_model_os_type    price part_of_day  request_cnt  ...   age  \
# 0                       iOS  20368.0     morning            1  ...   NaN
# 1                       iOS  20368.0     morning            1  ...   NaN
# 2                       iOS  20368.0         day            1  ...   NaN
# 3                       iOS  20368.0         day            1  ...   NaN
# 4                       iOS  20368.0         day            1  ...   NaN
# ...                     ...      ...         ...          ...  ...   ...
# 322899430           Android  16376.0     morning            1  ...  57.0
# 322899431           Android  16376.0     evening            1  ...  57.0
# 322899432           Android  16376.0         day            1  ...  57.0
# 322899433           Android  16376.0     evening            1  ...  57.0
# 322899434           Android  16376.0       night            1  ...  57.0
#
#            is_male  year  month  day  day_of_year  day_of_week      holiday  \
# 0              NaN  2022      6   15          166            2  Не праздник
# 1              NaN  2022      6   19          170            6  Не праздник
# 2              NaN  2022      6   12          163            6  День России
# 3              NaN  2022      5   16          136            0  Не праздник
# 4              NaN  2022      5   30          150            0  Не праздник
# ...            ...   ...    ...  ...          ...          ...          ...
# 322899430      0.0  2021      7   12          193            0  Не праздник
# 322899431      0.0  2021      6   20          171            6  Не праздник
# 322899432      0.0  2021      8    5          217            3  Не праздник
# 322899433      0.0  2021      7   19          200            0  Не праздник
# 322899434      0.0  2021      8    9          221            0  Не праздник
#
#                      datetime    timestamp
# 0         2022-06-15 09:00:00  165528360.0
# 1         2022-06-19 09:00:00  165562920.0
# 2         2022-06-12 15:00:00  165504600.0
# 3         2022-05-16 15:00:00  165271320.0
# 4         2022-05-30 15:00:00  165392280.0
# ...                       ...          ...
# 322899430 2021-07-12 09:00:00  162608040.0
# 322899431 2021-06-20 21:00:00  162422280.0
# 322899432 2021-08-05 15:00:00  162817560.0
# 322899433 2021-07-19 21:00:00  162672840.0
# 322899434 2021-08-09 03:00:00  162847800.0
#
# [322899435 rows x 21 columns]

# %%
df = df.drop(labels=["datetime"], axis=1)
gc.collect()
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#   part_of_day  request_cnt  user_id  age  is_male  year  month  day  \
# 0     morning            1    45098  NaN      NaN  2022      6   15
# 1     morning            1    45098  NaN      NaN  2022      6   19
# 2         day            1    45098  NaN      NaN  2022      6   12
# 3         day            1    45098  NaN      NaN  2022      5   16
# 4         day            1    45098  NaN      NaN  2022      5   30
#
#    day_of_year  day_of_week      holiday    timestamp
# 0          166            2  Не праздник  165528360.0
# 1          170            6  Не праздник  165562920.0
# 2          163            6  День России  165504600.0
# 3          136            0  Не праздник  165271320.0
# 4          150            0  Не праздник  165392280.0

# %%
my_reset("df")
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
df.to_parquet(f"../sequence_catboost_data/stages/stage_1.parquet.gzip",
              compression='gzip')

# %%
df = pd.read_parquet("../sequence_catboost_data/stages/stage_1.parquet.gzip")
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#   part_of_day  request_cnt  user_id  age  is_male  year  month  day  \
# 0     morning            1    45098  NaN      NaN  2022      6   15
# 1     morning            1    45098  NaN      NaN  2022      6   19
# 2         day            1    45098  NaN      NaN  2022      6   12
# 3         day            1    45098  NaN      NaN  2022      5   16
# 4         day            1    45098  NaN      NaN  2022      5   30
#
#    day_of_year  day_of_week      holiday    timestamp
# 0          166            2  Не праздник  165528360.0
# 1          170            6  Не праздник  165562920.0
# 2          163            6  День России  165504600.0
# 3          136            0  Не праздник  165271320.0
# 4          150            0  Не праздник  165392280.0

# %%
df = map_prices(df)
df.head()
# Out:
#           region_name  city_name cpe_manufacturer_name cpe_model_name  \
# 0  Краснодарский край  Краснодар                 Apple       iPhone 7
# 1  Краснодарский край  Краснодар                 Apple       iPhone 7
# 2  Краснодарский край  Краснодар                 Apple       iPhone 7
# 3  Краснодарский край  Краснодар                 Apple       iPhone 7
# 4  Краснодарский край  Краснодар                 Apple       iPhone 7
#
#                       url_host cpe_type_cd cpe_model_os_type    price  \
# 0                ad.adriver.ru  smartphone               iOS  20368.0
# 1                    apple.com  smartphone               iOS  20368.0
# 2       avatars.mds.yandex.net  smartphone               iOS  20368.0
# 3  googleads.g.doubleclick.net  smartphone               iOS  20368.0
# 4  googleads.g.doubleclick.net  smartphone               iOS  20368.0
#
#   part_of_day  request_cnt  user_id  age  is_male  year  month  day  \
# 0     morning            1    45098  NaN      NaN  2022      6   15
# 1     morning            1    45098  NaN      NaN  2022      6   19
# 2         day            1    45098  NaN      NaN  2022      6   12
# 3         day            1    45098  NaN      NaN  2022      5   16
# 4         day            1    45098  NaN      NaN  2022      5   30
#
#    day_of_year  day_of_week      holiday    timestamp
# 0          166            2  Не праздник  165528360.0
# 1          170            6  Не праздник  165562920.0
# 2          163            6  День России  165504600.0
# 3          136            0  Не праздник  165271320.0
# 4          150            0  Не праздник  165392280.0

# %%
df = df.drop(columns=["age"]).dropna(subset=["is_male"])
df
# Out:
#                        region_name        city_name cpe_manufacturer_name  \
# 2272               Санкт-Петербург  Санкт-Петербург               Samsung
# 2273               Санкт-Петербург  Санкт-Петербург               Samsung
# 2274               Санкт-Петербург  Санкт-Петербург               Samsung
# 2275       Калининградская область      Калининград               Samsung
# 2276               Санкт-Петербург  Санкт-Петербург               Samsung
# ...                            ...              ...                   ...
# 322899430        Калужская область          Обнинск               Samsung
# 322899431        Калужская область          Обнинск               Samsung
# 322899432        Калужская область          Обнинск               Samsung
# 322899433        Калужская область          Обнинск               Samsung
# 322899434        Калужская область          Обнинск               Samsung
#
#              cpe_model_name                     url_host cpe_type_cd  \
# 2272            Galaxy S20+                   ad.mail.ru  smartphone
# 2273            Galaxy S20+                  i.ytimg.com  smartphone
# 2274            Galaxy S20+     node3.online.sberbank.ru  smartphone
# 2275            Galaxy S20+     node3.online.sberbank.ru  smartphone
# 2276            Galaxy S20+              play.google.com  smartphone
# ...                     ...                          ...         ...
# 322899430  Galaxy A30s Dual       avatars.mds.yandex.net  smartphone
# 322899431  Galaxy A30s Dual  googleads.g.doubleclick.net  smartphone
# 322899432  Galaxy A30s Dual           online.sberbank.ru  smartphone
# 322899433  Galaxy A30s Dual                  s0.2mdn.net  smartphone
# 322899434  Galaxy A30s Dual                zen.yandex.ru  smartphone
#
#           cpe_model_os_type    price part_of_day  request_cnt  user_id  \
# 2272                Android  74259.0       night            1    79395
# 2273                Android  74259.0         day            3    79395
# 2274                Android  74259.0         day            3    79395
# 2275                Android  74259.0     evening            2    79395
# 2276                Android  74259.0         day            1    79395
# ...                     ...      ...         ...          ...      ...
# 322899430           Android  16376.0     morning            1   300964
# 322899431           Android  16376.0     evening            1   300964
# 322899432           Android  16376.0         day            1   300964
# 322899433           Android  16376.0     evening            1   300964
# 322899434           Android  16376.0       night            1   300964
#
#            is_male  year  month  day  day_of_year  day_of_week      holiday  \
# 2272           1.0  2021      9   26          269            6  Не праздник
# 2273           1.0  2021      8   21          233            5  Не праздник
# 2274           1.0  2021      8   20          232            4  Не праздник
# 2275           1.0  2021      9    9          252            3  Не праздник
# 2276           1.0  2021      8   30          242            0  Не праздник
# ...            ...   ...    ...  ...          ...          ...          ...
# 322899430      0.0  2021      7   12          193            0  Не праздник
# 322899431      0.0  2021      6   20          171            6  Не праздник
# 322899432      0.0  2021      8    5          217            3  Не праздник
# 322899433      0.0  2021      7   19          200            0  Не праздник
# 322899434      0.0  2021      8    9          221            0  Не праздник
#
#              timestamp
# 2272       163262520.0
# 2273       162955800.0
# 2274       162947160.0
# 2275       163122120.0
# 2276       163033560.0
# ...                ...
# 322899430  162608040.0
# 322899431  162422280.0
# 322899432  162817560.0
# 322899433  162672840.0
# 322899434  162847800.0
#
# [206840066 rows x 19 columns]

# %%
my_reset("df")
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
df.to_parquet("../sequence_catboost_data/stages/stage_2_is_male.parquet.gzip",
              compression='gzip')

# %%
df_is_male = pd.read_parquet("../sequence_catboost_data/stages/stage_2_is_male.parquet.gzip")
df_is_male.head()
# Out:
#                   region_name        city_name cpe_manufacturer_name  \
# 2272          Санкт-Петербург  Санкт-Петербург               Samsung
# 2273          Санкт-Петербург  Санкт-Петербург               Samsung
# 2274          Санкт-Петербург  Санкт-Петербург               Samsung
# 2275  Калининградская область      Калининград               Samsung
# 2276          Санкт-Петербург  Санкт-Петербург               Samsung
#
#      cpe_model_name                  url_host cpe_type_cd cpe_model_os_type  \
# 2272    Galaxy S20+                ad.mail.ru  smartphone           Android
# 2273    Galaxy S20+               i.ytimg.com  smartphone           Android
# 2274    Galaxy S20+  node3.online.sberbank.ru  smartphone           Android
# 2275    Galaxy S20+  node3.online.sberbank.ru  smartphone           Android
# 2276    Galaxy S20+           play.google.com  smartphone           Android
#
#         price part_of_day  request_cnt  user_id  is_male  year  month  day  \
# 2272  74259.0       night            1    79395      1.0  2021      9   26
# 2273  74259.0         day            3    79395      1.0  2021      8   21
# 2274  74259.0         day            3    79395      1.0  2021      8   20
# 2275  74259.0     evening            2    79395      1.0  2021      9    9
# 2276  74259.0         day            1    79395      1.0  2021      8   30
#
#       day_of_year  day_of_week      holiday    timestamp
# 2272          269            6  Не праздник  163262520.0
# 2273          233            5  Не праздник  162955800.0
# 2274          232            4  Не праздник  162947160.0
# 2275          252            3  Не праздник  163122120.0
# 2276          242            0  Не праздник  163033560.0

# %%
FE_DATA = "../fe_data/"
userfe = UserFE()
userfe.load(path=f"{FE_DATA}/USER_FE.parquet.gzip")
userfe.df = userfe.df[["user_id", 
                       "evening", 
                       "day", 
                       "night", 
                       "morning", 
                       "timespan", 
                       "url_host_mode_0", 
                       "url_host_mode_1",
                       "als_emb_url_request_sum_53",
                       "als_emb_url_request_sum_27",
                       "als_emb_url_request_sum_15",
                       "als_emb_url_request_sum_17",
                       "als_emb_url_request_sum_81"]]
# Out:
# Memory usage of dataframe is 282.01 MB
#   0%|          | 0/143 [00:00<?, ?it/s]
# Memory usage after optimization is: 248.74 MB
# Decreased by 11.8%

# %%
df_is_male = df_is_male.merge(userfe.df, on="user_id", how="left")
df_is_male
# Out:
#                        region_name        city_name cpe_manufacturer_name  \
# 0                  Санкт-Петербург  Санкт-Петербург               Samsung
# 1                  Санкт-Петербург  Санкт-Петербург               Samsung
# 2                  Санкт-Петербург  Санкт-Петербург               Samsung
# 3          Калининградская область      Калининград               Samsung
# 4                  Санкт-Петербург  Санкт-Петербург               Samsung
# ...                            ...              ...                   ...
# 206840061        Калужская область          Обнинск               Samsung
# 206840062        Калужская область          Обнинск               Samsung
# 206840063        Калужская область          Обнинск               Samsung
# 206840064        Калужская область          Обнинск               Samsung
# 206840065        Калужская область          Обнинск               Samsung
#
#              cpe_model_name                     url_host cpe_type_cd  \
# 0               Galaxy S20+                   ad.mail.ru  smartphone
# 1               Galaxy S20+                  i.ytimg.com  smartphone
# 2               Galaxy S20+     node3.online.sberbank.ru  smartphone
# 3               Galaxy S20+     node3.online.sberbank.ru  smartphone
# 4               Galaxy S20+              play.google.com  smartphone
# ...                     ...                          ...         ...
# 206840061  Galaxy A30s Dual       avatars.mds.yandex.net  smartphone
# 206840062  Galaxy A30s Dual  googleads.g.doubleclick.net  smartphone
# 206840063  Galaxy A30s Dual           online.sberbank.ru  smartphone
# 206840064  Galaxy A30s Dual                  s0.2mdn.net  smartphone
# 206840065  Galaxy A30s Dual                zen.yandex.ru  smartphone
#
#           cpe_model_os_type    price part_of_day  request_cnt  ...     night  \
# 0                   Android  74259.0       night            1  ...  0.109480
# 1                   Android  74259.0         day            3  ...  0.109480
# 2                   Android  74259.0         day            3  ...  0.109480
# 3                   Android  74259.0     evening            2  ...  0.109480
# 4                   Android  74259.0         day            1  ...  0.109480
# ...                     ...      ...         ...          ...  ...       ...
# 206840061           Android  16376.0     morning            1  ...  0.161725
# 206840062           Android  16376.0     evening            1  ...  0.161725
# 206840063           Android  16376.0         day            1  ...  0.161725
# 206840064           Android  16376.0     evening            1  ...  0.161725
# 206840065           Android  16376.0       night            1  ...  0.161725
#
#             morning  timespan  url_host_mode_0              url_host_mode_1  \
# 0          0.211621   43200.0      i.ytimg.com                    yandex.ru
# 1          0.211621   43200.0      i.ytimg.com                    yandex.ru
# 2          0.211621   43200.0      i.ytimg.com                    yandex.ru
# 3          0.211621   43200.0      i.ytimg.com                    yandex.ru
# 4          0.211621   43200.0      i.ytimg.com                    yandex.ru
# ...             ...       ...              ...                          ...
# 206840061  0.292004   56808.0        yandex.ru  googleads.g.doubleclick.net
# 206840062  0.292004   56808.0        yandex.ru  googleads.g.doubleclick.net
# 206840063  0.292004   56808.0        yandex.ru  googleads.g.doubleclick.net
# 206840064  0.292004   56808.0        yandex.ru  googleads.g.doubleclick.net
# 206840065  0.292004   56808.0        yandex.ru  googleads.g.doubleclick.net
#
#            als_emb_url_request_sum_53  als_emb_url_request_sum_27  \
# 0                            0.337429                    0.344958
# 1                            0.337429                    0.344958
# 2                            0.337429                    0.344958
# 3                            0.337429                    0.344958
# 4                            0.337429                    0.344958
# ...                               ...                         ...
# 206840061                    0.100901                    0.393608
# 206840062                    0.100901                    0.393608
# 206840063                    0.100901                    0.393608
# 206840064                    0.100901                    0.393608
# 206840065                    0.100901                    0.393608
#
#           als_emb_url_request_sum_15  als_emb_url_request_sum_17  \
# 0                           0.111196                    0.801757
# 1                           0.111196                    0.801757
# 2                           0.111196                    0.801757
# 3                           0.111196                    0.801757
# 4                           0.111196                    0.801757
# ...                              ...                         ...
# 206840061                  -0.193072                    0.951323
# 206840062                  -0.193072                    0.951323
# 206840063                  -0.193072                    0.951323
# 206840064                  -0.193072                    0.951323
# 206840065                  -0.193072                    0.951323
#
#            als_emb_url_request_sum_81
# 0                           -0.399860
# 1                           -0.399860
# 2                           -0.399860
# 3                           -0.399860
# 4                           -0.399860
# ...                               ...
# 206840061                   -0.193426
# 206840062                   -0.193426
# 206840063                   -0.193426
# 206840064                   -0.193426
# 206840065                   -0.193426
#
# [206840066 rows x 31 columns]

# %%
cat_features = list(df_is_male.columns[np.where(df_is_male.dtypes == object)])

# %%
cbe = CatBoostEncoderWrapper(cat_features=cat_features, sort_col="timestamp", n_folds=10)

# %%
df_is_male = cbe.fit_transform(df_is_male, target_col="is_male")
# Out:
# 0it [00:00, ?it/s]

# %%
cbe.save("../model_zoo", "is_male_cbe_seq_catboost")

# %%
my_reset("df_is_male")

# %%
df_is_male.to_parquet(f"../sequence_catboost_data/stages/stage_3_is_male.parquet.gzip",
              compression='gzip')

# %%
df_is_male = pandas_reduce_mem_usage(pd.read_parquet("../sequence_catboost_data/stages/stage_3_is_male.parquet.gzip"))
df_is_male.head()
# Out:
# Memory usage of dataframe is 22092.90 MB
#   0%|          | 0/19 [00:00<?, ?it/s]
# Memory usage after optimization is: 13413.55 MB
# Decreased by 39.3%
#            region_name  city_name  cpe_manufacturer_name  cpe_model_name  \
# 72036835      0.492813   0.475856               0.523871        0.527727
# 269481717     0.460119   0.468477               0.505041        0.491774
# 83105451      0.575031   0.585275               0.497987        0.388630
# 210293403     0.515135   0.533519               0.505041        0.470685
# 269479580     0.522969   0.522969               0.505041        0.443390
#
#            url_host  cpe_type_cd  cpe_model_os_type    price  part_of_day  \
# 72036835   0.515649     0.520669           0.534969  14990.0     0.559003
# 269481717  0.508047     0.520669           0.534969  17985.0     0.559003
# 83105451   0.522636     0.520669           0.497987  45328.0     0.559003
# 210293403  0.485715     0.520669           0.534969  28788.0     0.559003
# 269479580  0.544725     0.520669           0.534969  13190.0     0.559003
#
#            request_cnt  user_id  year  month  day  day_of_year  day_of_week  \
# 72036835             1    88235  2021      6   16          167            2
# 269481717            1   160508  2021      6   16          167            2
# 83105451             4   113128  2021      6   16          167            2
# 210293403            3    66732  2021      6   16          167            2
# 269479580            2   168799  2021      6   16          167            2
#
#             holiday    timestamp  is_male
# 72036835   0.520504  162381248.0      0.0
# 269481717  0.520504  162381248.0      0.0
# 83105451   0.520504  162381248.0      0.0
# 210293403  0.520504  162381248.0      1.0
# 269479580  0.520504  162381248.0      1.0

# %%
df_is_male = generate_time_lags(df_is_male, 
                                shift_column="url_host", 
                                time_column="timestamp", 
                                n_lags=10).fillna(-1)
df_is_male.head()
# Out:
#            region_name  city_name  cpe_manufacturer_name  cpe_model_name  \
# 179123993     0.579224   0.579224               0.505070        0.437066
# 179124074     0.579238   0.579238               0.505052        0.437486
# 179124075     0.579238   0.579238               0.505041        0.437431
# 179123969     0.579292   0.579292               0.505097        0.436958
# 179124057     0.579241   0.579241               0.505036        0.437167
#
#            url_host  cpe_type_cd  cpe_model_os_type   price  part_of_day  \
# 179123993  0.485884     0.520642           0.534937  2990.0     0.510756
# 179124074  0.489935     0.520676           0.534976  2990.0     0.510796
# 179124075  0.522636     0.520669           0.534969  2990.0     0.513743
# 179123969  0.522641     0.520681           0.534986  2990.0     0.559007
# 179124057  0.511697     0.520663           0.534955  2990.0     0.525651
#
#            request_cnt  ...  lag_url_host_1  lag_url_host_2  lag_url_host_3  \
# 179123993            1  ...       -1.000000       -1.000000       -1.000000
# 179124074            1  ...        0.485884       -1.000000       -1.000000
# 179124075            1  ...        0.489935        0.485884       -1.000000
# 179123969            1  ...        0.522636        0.489935        0.485884
# 179124057            1  ...        0.522641        0.522636        0.489935
#
#            lag_url_host_4  lag_url_host_5  lag_url_host_6  lag_url_host_7  \
# 179123993       -1.000000            -1.0            -1.0            -1.0
# 179124074       -1.000000            -1.0            -1.0            -1.0
# 179124075       -1.000000            -1.0            -1.0            -1.0
# 179123969       -1.000000            -1.0            -1.0            -1.0
# 179124057        0.485884            -1.0            -1.0            -1.0
#
#            lag_url_host_8  lag_url_host_9  lag_url_host_10
# 179123993            -1.0            -1.0             -1.0
# 179124074            -1.0            -1.0             -1.0
# 179124075            -1.0            -1.0             -1.0
# 179123969            -1.0            -1.0             -1.0
# 179124057            -1.0            -1.0             -1.0
#
# [5 rows x 29 columns]

# %%
df_is_male = generate_time_lags(df_is_male, 
                                shift_column="timestamp", 
                                time_column="timestamp", 
                                n_lags=5).fillna(0)

# %%
df_is_male = generate_time_lags(df_is_male, 
                                shift_column="city_name", 
                                time_column="timestamp", 
                                n_lags=1).fillna(0)

# %%
my_reset("df_is_male")
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? н
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
df_is_male.to_parquet(f"../sequence_catboost_data/stages/stage_4_is_male.parquet.gzip",
              compression='gzip')

# %% [markdown]
# # CatBoost

# %%
import warnings

import numpy as np
import pandas as pd
import random
import torch
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

import sys
import os
import gc
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ["USE_OPENMP"] = '1'

from sklearn.metrics import roc_auc_score

sys.path.append(os.path.abspath("../"))
from fe_modules.aggregates import get_agg_count, get_agg_sum, get_top_n_mode, \
                                  get_agg_mean, get_agg_max, get_agg_min, \
                                  get_agg_median, get_agg_std, get_agg_nunique, \
                                  get_price_of_all_cpes, get_ratio_part_of_day
from fe_modules.cyclical_features import generate_cyclical_features
from fe_modules.datetime_features import get_year, get_month, get_day, \
                                         get_timestamp, get_day_of_year, \
                                         get_day_of_week, get_holiday_name, \
                                         part_of_day_to_hour, add_hour_to_date, \
                                         get_relative_time, mean_first_visit, \
                                         mean_last_visit
from fe_modules.encoders import TargetEncoderWrapper
from fe_modules.feature_merges import add_cat_features
from fe_modules.geo_features import map_cities, geo_dist, dist_to_large_cities, \
                                    map_grid, MapGridTransformer
from fe_modules.missing import map_prices
from fe_modules.preprocessing import clean_os_type
from fe_modules.text_manipulation import get_domain
from fe_modules.time_lags import generate_time_lags
from fe_modules.recsys_features import ALSWrapper, RecVAEWrapper

from fe_modules.user_fe import UserFE

from modules.memory_utils import pandas_reduce_mem_usage

from seq2seq_modules.metrics import GENDER_METRIC


def my_reset(*varnames):
    """
    varnames are what you want to keep
    """
    globals_ = globals()
    to_save = {v: globals_[v] for v in varnames}
    to_save['my_reset'] = my_reset  # lets keep this function by default
    del globals_
    get_ipython().magic("reset")
    globals().update(to_save)
    

random_state = 69

random.seed(random_state),
np.random.seed(random_state)
torch.manual_seed(random_state)
torch.cuda.manual_seed_all(random_state)

# %%
import pandas as pd
import numpy as np
from catboost import Pool
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from catboost.utils import get_gpu_device_count

from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
from sklearn.inspection import permutation_importance

from catboost_modules.metrics import GENDER_METRIC
from seq2seq_modules.utils import numpy_age_bucket

# %%
df_is_male = pandas_reduce_mem_usage(pd.read_parquet(f"../sequence_catboost_data/stages/stage_4_is_male.parquet.gzip"))
df_is_male
# Out:
# Memory usage of dataframe is 26038.06 MB
#   0%|          | 0/35 [00:00<?, ?it/s]
# Memory usage after optimization is: 26038.06 MB
# Decreased by 0.0%
#            region_name  city_name  cpe_manufacturer_name  cpe_model_name  \
# 179123993     0.579224   0.579224               0.505070        0.437066
# 179124074     0.579238   0.579238               0.505052        0.437486
# 179124075     0.579238   0.579238               0.505041        0.437431
# 179123969     0.579292   0.579292               0.505097        0.436958
# 179124057     0.579241   0.579241               0.505036        0.437167
# ...                ...        ...                    ...             ...
# 219235306     0.479846   0.502942               0.586680        0.592065
# 277230213     0.515381   0.483720               0.523893        0.549565
# 316271590     0.395068   0.401789               0.523858        0.489358
# 258443456     0.535242   0.581704               0.523790        0.489245
# 51904533      0.487507   0.501588               0.586560        0.461460
#
#            url_host  cpe_type_cd  cpe_model_os_type    price  part_of_day  \
# 179123993  0.485884     0.520642           0.534937   2990.0     0.510756
# 179124074  0.489935     0.520676           0.534976   2990.0     0.510796
# 179124075  0.522636     0.520669           0.534969   2990.0     0.513743
# 179123969  0.522641     0.520681           0.534986   2990.0     0.559007
# 179124057  0.511697     0.520663           0.534955   2990.0     0.525651
# ...             ...          ...                ...      ...          ...
# 219235306  0.522729     0.520675           0.534980  10054.0     0.525675
# 277230213  0.528831     0.520676           0.534976  16077.0     0.513726
# 316271590  0.448803     0.520669           0.534974   7990.0     0.513676
# 258443456  0.522569     0.520642           0.534937   7947.0     0.510756
# 51904533   0.545333     0.520669           0.534974   4790.0     0.510839
#
#            request_cnt  ...  lag_url_host_7  lag_url_host_8  lag_url_host_9  \
# 179123993            1  ...            -1.0            -1.0            -1.0
# 179124074            1  ...            -1.0            -1.0            -1.0
# 179124075            1  ...            -1.0            -1.0            -1.0
# 179123969            1  ...            -1.0            -1.0            -1.0
# 179124057            1  ...            -1.0            -1.0            -1.0
# ...                ...  ...             ...             ...             ...
# 219235306            1  ...            -1.0            -1.0            -1.0
# 277230213            1  ...            -1.0            -1.0            -1.0
# 316271590            1  ...            -1.0            -1.0            -1.0
# 258443456            1  ...            -1.0            -1.0            -1.0
# 51904533             1  ...            -1.0            -1.0            -1.0
#
#            lag_url_host_10  lag_timestamp_1  lag_timestamp_2  lag_timestamp_3  \
# 179123993             -1.0              0.0              0.0              0.0
# 179124074             -1.0      162385568.0              0.0              0.0
# 179124075             -1.0      162385568.0      162385568.0              0.0
# 179123969             -1.0      162387712.0      162385568.0      162385568.0
# 179124057             -1.0      162407168.0      162387712.0      162385568.0
# ...                    ...              ...              ...              ...
# 219235306             -1.0              0.0              0.0              0.0
# 277230213             -1.0              0.0              0.0              0.0
# 316271590             -1.0              0.0              0.0              0.0
# 258443456             -1.0              0.0              0.0              0.0
# 51904533              -1.0              0.0              0.0              0.0
#
#            lag_timestamp_4  lag_timestamp_5  lag_city_name_1
# 179123993              0.0              0.0         0.000000
# 179124074              0.0              0.0         0.579224
# 179124075              0.0              0.0         0.579238
# 179123969              0.0              0.0         0.579238
# 179124057      162385568.0              0.0         0.579292
# ...                    ...              ...              ...
# 219235306              0.0              0.0         0.000000
# 277230213              0.0              0.0         0.000000
# 316271590              0.0              0.0         0.000000
# 258443456              0.0              0.0         0.000000
# 51904533               0.0              0.0         0.000000
#
# [206840066 rows x 35 columns]

# %% [markdown]
# #### Add seq2seq features

# %%
def coss_val_score(model, df, target_feature, metric, n_folds=5, random_state=42, calculate_importance=True):
    users = df['user_id']
    
    scores = []
    models = []
    
#     importances = pd.DataFrame({"Feature Id": X.columns, 
#                                 "Importance": np.zeros(X.columns.shape[0]), 
#                                 "std": np.zeros(X.columns.shape[0])})
    
    skf = StratifiedGroupKFold(n_splits=n_folds, random_state=random_state, shuffle=True)
    for i, (train_index, val_index) in enumerate(skf.split(df, df[target_feature], users)):
        X_train, X_val = df.drop(columns=[target_feature, 'user_id']).iloc[train_index], df.drop(columns=[target_feature, 'user_id']).iloc[val_index]
        y_train, y_val = df[target_feature].iloc[train_index], df[target_feature].iloc[val_index]
        
        model.fit(X_train,
                  y_train,
                  eval_set=(X_val, y_val), 
                  use_best_model=True)
        models.append(model)
        
        if target_feature == "age":
            preds = model.predict_proba(X_val)
            score = metric(preds, y_val)

        elif target_feature == "is_male":
            preds = pd.DataFrame({
                "user_id": users.iloc[val_index], 
                "proba": model.predict_proba(X_val)[:, 1],
                f"{target_feature}": y_val
            })
            
            final_preds = preds.groupby("user_id").agg({
                "proba": np.mean,
                f"{target_feature}": pd.Series.mode
            })
            
            final_preds[f"{target_feature}"] = final_preds[f"{target_feature}"].astype(int)
                        
            score = 2 * roc_auc_score(
                final_preds[f"{target_feature}"].to_numpy(),
                final_preds["proba"].to_numpy()
            ) - 1
            
            

        
        scores.append(score)
        print(f"Fold {i}: {score}")
        
#         if calculate_importance:
#             r = permutation_importance(model, 
#                                        X_val, 
#                                        y_val,
#                                        n_repeats=10,
#                                        random_state=42)
        
        
#             importances["Importance"] += r.importances_mean
#             importances["std"] += r.importances_std
        
#         for i in r.importances_mean.argsort()[::-1]:
#             print(f"{X_val.columns[i]}")
#             print(f"{r.importances_mean[i]}")
            

    importances["Importance"] /= n_folds      
    importances["std"] /= n_folds      
    importances["good"] = importances["Importance"] - 2 * importances["std"] > 0
    
    return (models, (sum(scores) / n_folds), importances, X.columns)

# %%
params = {"loss_function": "CrossEntropy",
          "eval_metric": "NormalizedGini",
          "verbose": 1,
          "iterations": 50,
          "random_state": 42,
          "task_type": "GPU" if get_gpu_device_count() else "CPU",
          "early_stopping_rounds": 100,
          "use_best_model": True,
          "bootstrap_type": 'Poisson',
          "subsample": 0.3,
         }

model_is_male = CatBoostClassifier(**params)

# %%
is_male_models, scores, is_male_importances, features = coss_val_score(
    model=model_is_male, 
    df=df_is_male, 
    target_feature="is_male", 
    metric=GENDER_METRIC, 
    calculate_importance=False
)

print(scores)
# Out:
# Default metric period is 5 because NormalizedGini is/are not implemented for GPU
# Metric NormalizedGini is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	test: 0.2216762	best: 0.2216762 (0)	total: 4.43s	remaining: 3m 36s
# 1:	total: 8.7s	remaining: 3m 28s
# 2:	total: 13s	remaining: 3m 23s
# 3:	total: 17.4s	remaining: 3m 19s
# 4:	total: 21.8s	remaining: 3m 15s
# 5:	test: 0.3150001	best: 0.3150001 (5)	total: 26.1s	remaining: 3m 11s
# 6:	total: 30.5s	remaining: 3m 7s
# 7:	total: 34.9s	remaining: 3m 3s
# 8:	total: 39.3s	remaining: 2m 59s
# 9:	total: 43.7s	remaining: 2m 54s
# 10:	test: 0.3346159	best: 0.3346159 (10)	total: 48.1s	remaining: 2m 50s
# 11:	total: 52.5s	remaining: 2m 46s
# 12:	total: 56.9s	remaining: 2m 41s
# 13:	total: 1m 1s	remaining: 2m 37s
# 14:	total: 1m 5s	remaining: 2m 33s
# 15:	test: 0.3506085	best: 0.3506085 (15)	total: 1m 10s	remaining: 2m 29s
# 16:	total: 1m 14s	remaining: 2m 24s
# 17:	total: 1m 19s	remaining: 2m 20s
# 18:	total: 1m 23s	remaining: 2m 16s
# 19:	total: 1m 27s	remaining: 2m 11s
# 20:	test: 0.3636302	best: 0.3636302 (20)	total: 1m 32s	remaining: 2m 7s
# 21:	total: 1m 36s	remaining: 2m 3s
# 22:	total: 1m 41s	remaining: 1m 58s
# 23:	total: 1m 45s	remaining: 1m 54s
# 24:	total: 1m 50s	remaining: 1m 50s
# 25:	test: 0.3745977	best: 0.3745977 (25)	total: 1m 54s	remaining: 1m 45s
# 26:	total: 1m 59s	remaining: 1m 41s
# 27:	total: 2m 3s	remaining: 1m 37s
# 28:	total: 2m 8s	remaining: 1m 32s
# 29:	total: 2m 12s	remaining: 1m 28s
# 30:	test: 0.3809929	best: 0.3809929 (30)	total: 2m 17s	remaining: 1m 23s
# 31:	total: 2m 21s	remaining: 1m 19s
# 32:	total: 2m 26s	remaining: 1m 15s
# 33:	total: 2m 30s	remaining: 1m 10s
# 34:	total: 2m 34s	remaining: 1m 6s
# 35:	test: 0.3893898	best: 0.3893898 (35)	total: 2m 39s	remaining: 1m 1s
# 36:	total: 2m 43s	remaining: 57.6s
# 37:	total: 2m 48s	remaining: 53.2s
# 38:	total: 2m 52s	remaining: 48.8s
# 39:	total: 2m 57s	remaining: 44.3s
# 40:	test: 0.3960863	best: 0.3960863 (40)	total: 3m 1s	remaining: 39.9s
# 41:	total: 3m 6s	remaining: 35.5s
# 42:	total: 3m 10s	remaining: 31s
# 43:	total: 3m 15s	remaining: 26.6s
# 44:	total: 3m 19s	remaining: 22.2s
# 45:	test: 0.4008238	best: 0.4008238 (45)	total: 3m 24s	remaining: 17.8s
# 46:	total: 3m 28s	remaining: 13.3s
# 47:	total: 3m 33s	remaining: 8.88s
# 48:	total: 3m 37s	remaining: 4.44s
# 49:	test: 0.4047779	best: 0.4047779 (49)	total: 3m 42s	remaining: 0us
# bestTest = 0.4047779413
# bestIteration = 49
# Fold 0: 0.42367760132044263
# Default metric period is 5 because NormalizedGini is/are not implemented for GPU
# Metric NormalizedGini is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# 0:	test: 0.2298637	best: 0.2298637 (0)	total: 4.52s	remaining: 3m 41s
# 1:	total: 8.8s	remaining: 3m 31s
# 2:	total: 13.1s	remaining: 3m 25s
# 3:	total: 17.4s	remaining: 3m 20s
# 4:	total: 21.8s	remaining: 3m 16s
# 5:	test: 0.3219957	best: 0.3219957 (5)	total: 26.2s	remaining: 3m 11s
# 6:	total: 30.5s	remaining: 3m 7s
# 7:	total: 34.9s	remaining: 3m 3s
# 8:	total: 39.3s	remaining: 2m 58s
# 9:	total: 43.7s	remaining: 2m 54s
# 10:	test: 0.3403721	best: 0.3403721 (10)	total: 48.1s	remaining: 2m 50s
# 11:	total: 52.5s	remaining: 2m 46s
# 12:	total: 56.9s	remaining: 2m 42s
# 13:	total: 1m 1s	remaining: 2m 37s
# 14:	total: 1m 5s	remaining: 2m 33s
# 15:	test: 0.3568167	best: 0.3568167 (15)	total: 1m 10s	remaining: 2m 29s
# 16:	total: 1m 14s	remaining: 2m 24s
# 17:	total: 1m 19s	remaining: 2m 20s
# 18:	total: 1m 23s	remaining: 2m 16s
# 19:	total: 1m 27s	remaining: 2m 11s
# 20:	test: 0.3700080	best: 0.3700080 (20)	total: 1m 32s	remaining: 2m 7s
# 21:	total: 1m 36s	remaining: 2m 3s
# 22:	total: 1m 41s	remaining: 1m 58s
# 23:	total: 1m 45s	remaining: 1m 54s
# 24:	total: 1m 50s	remaining: 1m 50s
# 25:	test: 0.3786378	best: 0.3786378 (25)	total: 1m 54s	remaining: 1m 45s
# 26:	total: 1m 59s	remaining: 1m 41s
# 27:	total: 2m 3s	remaining: 1m 37s
# 28:	total: 2m 8s	remaining: 1m 32s
# 29:	total: 2m 12s	remaining: 1m 28s
# 30:	test: 0.3888722	best: 0.3888722 (30)	total: 2m 17s	remaining: 1m 24s
# 31:	total: 2m 21s	remaining: 1m 19s
# 32:	total: 2m 26s	remaining: 1m 15s
# 33:	total: 2m 30s	remaining: 1m 10s
# 34:	total: 2m 35s	remaining: 1m 6s
# 35:	test: 0.3969237	best: 0.3969237 (35)	total: 2m 39s	remaining: 1m 2s
# 36:	total: 2m 44s	remaining: 57.6s
# 37:	total: 2m 48s	remaining: 53.2s
# 38:	total: 2m 52s	remaining: 48.8s
# 39:	total: 2m 57s	remaining: 44.4s
# 40:	test: 0.4022969	best: 0.4022969 (40)	total: 3m 1s	remaining: 39.9s
# 41:	total: 3m 6s	remaining: 35.5s
# 42:	total: 3m 10s	remaining: 31.1s
# 43:	total: 3m 15s	remaining: 26.6s
# 44:	total: 3m 19s	remaining: 22.2s
# 45:	test: 0.4080495	best: 0.4080495 (45)	total: 3m 24s	remaining: 17.8s
# 46:	total: 3m 28s	remaining: 13.3s
# 47:	total: 3m 33s	remaining: 8.89s
# 48:	total: 3m 37s	remaining: 4.45s
# 49:	test: 0.4117029	best: 0.4117029 (49)	total: 3m 42s	remaining: 0us
# bestTest = 0.4117028604
# bestIteration = 49
# Fold 1: 0.44016831518898547

# %% [markdown]
# # Experiments
#
# * 0.24 Фичи начальные
# * 0.40 5 лагов url host
