# %%
import sys
import os
import warnings

sys.path.append(os.path.abspath("modules/"))
sys.path.append(os.path.abspath("fe_modules/"))
sys.path.append(os.path.abspath("seq2seq_modules/"))

os.environ['OPENBLAS_NUM_THREADS'] = '1'
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import time
import pyarrow.parquet as pq
import polars as pl
import scipy
import implicit
import bisect
import sklearn.metrics as m
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve, CalibratedClassifierCV

# %%
import importlib

import modules
import fe_modules

importlib.reload(modules)
importlib.reload(fe_modules)

from modules.memory_utils import polars_reduce_mem_usage

# %%
LOCAL_DATA_PATH = './context_data/'
SPLIT_SEED = 42
DATA_FILE = 'competition_data_final_pqt/'
TARGET_FILE = 'competition_target_pqt/'

# %%
df = polars_reduce_mem_usage(
    pl.read_parquet(
        f'context_data/competition_data_final_pqt/part-00000-aba60f69-2b63-4cc1-95ca-542598094698-c000.snappy.parquet'
    ))
df
# Out:
# Memory usage of dataframe is 6059.32 MB
# Memory usage of dataframe is 5.92 GB
# utf
# utf
# utf
# utf
# utf
# utf
# utf
# flo
# dat
# utf
# int
# int
# Memory usage after optimization is: 5592.42 MB
# Memory usage  after optimization is 5.46 GB
# Decreased by 7.7%
# shape: (32638709, 12)
# ┌───────────┬─────────┬────────────┬────────────┬─────┬──────────┬───────────┬───────────┬─────────┐
# │ region_na ┆ city_na ┆ cpe_manufa ┆ cpe_model_ ┆ ... ┆ date     ┆ part_of_d ┆ request_c ┆ user_id │
# │ me        ┆ me      ┆ cturer_nam ┆ name       ┆     ┆ ---      ┆ ay        ┆ nt        ┆ ---     │
# │ ---       ┆ ---     ┆ e          ┆ ---        ┆     ┆ date     ┆ ---       ┆ ---       ┆ i32     │
# │ str       ┆ str     ┆ ---        ┆ str        ┆     ┆          ┆ str       ┆ i8        ┆         │
# │           ┆         ┆ str        ┆            ┆     ┆          ┆           ┆           ┆         │
# ╞═══════════╪═════════╪════════════╪════════════╪═════╪══════════╪═══════════╪═══════════╪═════════╡
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ 2022-06- ┆ morning   ┆ 1         ┆ 45098   │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆ 15       ┆           ┆           ┆         │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ 2022-06- ┆ morning   ┆ 1         ┆ 45098   │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆ 19       ┆           ┆           ┆         │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ 2022-06- ┆ day       ┆ 1         ┆ 45098   │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆ 12       ┆           ┆           ┆         │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ 2022-05- ┆ day       ┆ 1         ┆ 45098   │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆ 16       ┆           ┆           ┆         │
# │ ...       ┆ ...     ┆ ...        ┆ ...        ┆ ... ┆ ...      ┆ ...       ┆ ...       ┆ ...     │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 2022-04- ┆ morning   ┆ 1         ┆ 162531  │
# │ область   ┆         ┆            ┆ 8          ┆     ┆ 11       ┆           ┆           ┆         │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 2022-04- ┆ evening   ┆ 1         ┆ 162531  │
# │ область   ┆         ┆            ┆ 8          ┆     ┆ 01       ┆           ┆           ┆         │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 2022-04- ┆ day       ┆ 2         ┆ 162531  │
# │ область   ┆         ┆            ┆ 8          ┆     ┆ 04       ┆           ┆           ┆         │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 2022-04- ┆ evening   ┆ 1         ┆ 162531  │
# │ область   ┆         ┆            ┆ 8          ┆     ┆ 17       ┆           ┆           ┆         │
# └───────────┴─────────┴────────────┴────────────┴─────┴──────────┴───────────┴───────────┴─────────┘

# %% [markdown]
# # Feature engeneering

# %%
from fe_modules.aggregates import get_agg_count, \
                                  get_agg_sum, \
                                  get_agg_mode, \
                                  get_agg_mean, \
                                  get_price_of_all_cpes, \
                                  get_agg_n_unique

from fe_modules.datetime import get_timestamp

# %%
df = get_timestamp(df, "date")
df
# Out:
# shape: (32638709, 13)
# ┌───────────┬─────────┬────────────┬────────────┬─────┬───────────┬───────────┬─────────┬─────────┐
# │ region_na ┆ city_na ┆ cpe_manufa ┆ cpe_model_ ┆ ... ┆ part_of_d ┆ request_c ┆ user_id ┆ timesta │
# │ me        ┆ me      ┆ cturer_nam ┆ name       ┆     ┆ ay        ┆ nt        ┆ ---     ┆ mp      │
# │ ---       ┆ ---     ┆ e          ┆ ---        ┆     ┆ ---       ┆ ---       ┆ i32     ┆ ---     │
# │ str       ┆ str     ┆ ---        ┆ str        ┆     ┆ str       ┆ i8        ┆         ┆ i64     │
# │           ┆         ┆ str        ┆            ┆     ┆           ┆           ┆         ┆         │
# ╞═══════════╪═════════╪════════════╪════════════╪═════╪═══════════╪═══════════╪═════════╪═════════╡
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ morning   ┆ 1         ┆ 45098   ┆ 1655251 │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆           ┆           ┆         ┆ 2000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ morning   ┆ 1         ┆ 45098   ┆ 1655596 │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆           ┆           ┆         ┆ 8000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ day       ┆ 1         ┆ 45098   ┆ 1654992 │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆           ┆           ┆         ┆ 0000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Краснодар ┆ Краснод ┆ Apple      ┆ iPhone 7   ┆ ... ┆ day       ┆ 1         ┆ 45098   ┆ 1652659 │
# │ ский край ┆ ар      ┆            ┆            ┆     ┆           ┆           ┆         ┆ 2000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ ...       ┆ ...     ┆ ...        ┆ ...        ┆ ... ┆ ...       ┆ ...       ┆ ...     ┆ ...     │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ morning   ┆ 1         ┆ 162531  ┆ 1649635 │
# │ область   ┆         ┆            ┆ 8          ┆     ┆           ┆           ┆         ┆ 2000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ evening   ┆ 1         ┆ 162531  ┆ 1648771 │
# │ область   ┆         ┆            ┆ 8          ┆     ┆           ┆           ┆         ┆ 2000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ day       ┆ 2         ┆ 162531  ┆ 1649030 │
# │ область   ┆         ┆            ┆ 8          ┆     ┆           ┆           ┆         ┆ 4000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# │ Самарская ┆ Самара  ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ evening   ┆ 1         ┆ 162531  ┆ 1650153 │
# │ область   ┆         ┆            ┆ 8          ┆     ┆           ┆           ┆         ┆ 6000000 │
# │           ┆         ┆            ┆            ┆     ┆           ┆           ┆         ┆ 00      │
# └───────────┴─────────┴────────────┴────────────┴─────┴───────────┴───────────┴─────────┴─────────┘

# %%
q = df.sort("timestamp").groupby("cpe_model_name").agg([pl.col("timestamp"), pl.col("price")])
q

# %%
df = get_agg_n_unique(df, target_col="price", alias="num_cpe")
df
# Out:
# shape: (32638709, 14)
# ┌───────────┬────────────┬────────────┬────────────┬─────┬───────────┬─────────┬─────────┬─────────┐
# │ region_na ┆ city_name  ┆ cpe_manufa ┆ cpe_model_ ┆ ... ┆ request_c ┆ user_id ┆ timesta ┆ num_cpe │
# │ me        ┆ ---        ┆ cturer_nam ┆ name       ┆     ┆ nt        ┆ ---     ┆ mp      ┆ ---     │
# │ ---       ┆ str        ┆ e          ┆ ---        ┆     ┆ ---       ┆ i32     ┆ ---     ┆ u32     │
# │ str       ┆            ┆ ---        ┆ str        ┆     ┆ i8        ┆         ┆ i64     ┆         │
# │           ┆            ┆ str        ┆            ┆     ┆           ┆         ┆         ┆         │
# ╞═══════════╪════════════╪════════════╪════════════╪═════╪═══════════╪═════════╪═════════╪═════════╡
# │ Краснодар ┆ Анапа      ┆ Huawei     ┆ Nova 3     ┆ ... ┆ 1         ┆ 4       ┆ 1626998 ┆ 1       │
# │ ский край ┆            ┆            ┆            ┆     ┆           ┆         ┆ 4000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Краснодар ┆ Анапа      ┆ Huawei     ┆ Nova 3     ┆ ... ┆ 1         ┆ 4       ┆ 1626998 ┆ 1       │
# │ ский край ┆            ┆            ┆            ┆     ┆           ┆         ┆ 4000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Краснодар ┆ Новороссий ┆ Huawei     ┆ Nova 3     ┆ ... ┆ 1         ┆ 4       ┆ 1626825 ┆ 1       │
# │ ский край ┆ ск         ┆            ┆            ┆     ┆           ┆         ┆ 6000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Краснодар ┆ Анапа      ┆ Huawei     ┆ Nova 3     ┆ ... ┆ 1         ┆ 4       ┆ 1627084 ┆ 1       │
# │ ский край ┆            ┆            ┆            ┆     ┆           ┆         ┆ 8000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ ...       ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...       ┆ ...     ┆ ...     ┆ ...     │
# │ Нижегород ┆ Нижний     ┆ Huawei     ┆ Y5 Prime   ┆ ... ┆ 2         ┆ 415277  ┆ 1624924 ┆ 1       │
# │ ская      ┆ Новгород   ┆            ┆ 2018       ┆     ┆           ┆         ┆ 8000000 ┆         │
# │ область   ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Хабаровск ┆ Хабаровск  ┆ Samsung    ┆ Galaxy A20 ┆ ... ┆ 1         ┆ 415305  ┆ 1627689 ┆ 1       │
# │ ий край   ┆            ┆            ┆ Dual       ┆     ┆           ┆         ┆ 6000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Хабаровск ┆ Хабаровск  ┆ Samsung    ┆ Galaxy A20 ┆ ... ┆ 1         ┆ 415305  ┆ 1627689 ┆ 1       │
# │ ий край   ┆            ┆            ┆ Dual       ┆     ┆           ┆         ┆ 6000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Хабаровск ┆ Хабаровск  ┆ Samsung    ┆ Galaxy A20 ┆ ... ┆ 1         ┆ 415305  ┆ 1627689 ┆ 1       │
# │ ий край   ┆            ┆            ┆ Dual       ┆     ┆           ┆         ┆ 6000000 ┆         │
# │           ┆            ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# └───────────┴────────────┴────────────┴────────────┴─────┴───────────┴─────────┴─────────┴─────────┘

# %%
q = df.filter(pl.col("num_cpe") > 1)
q
# Out:
# shape: (1113748, 14)
# ┌───────────┬───────────┬────────────┬────────────┬─────┬───────────┬─────────┬─────────┬─────────┐
# │ region_na ┆ city_name ┆ cpe_manufa ┆ cpe_model_ ┆ ... ┆ request_c ┆ user_id ┆ timesta ┆ num_cpe │
# │ me        ┆ ---       ┆ cturer_nam ┆ name       ┆     ┆ nt        ┆ ---     ┆ mp      ┆ ---     │
# │ ---       ┆ str       ┆ e          ┆ ---        ┆     ┆ ---       ┆ i32     ┆ ---     ┆ u32     │
# │ str       ┆           ┆ ---        ┆ str        ┆     ┆ i8        ┆         ┆ i64     ┆         │
# │           ┆           ┆ str        ┆            ┆     ┆           ┆         ┆         ┆         │
# ╞═══════════╪═══════════╪════════════╪════════════╪═════╪═══════════╪═════════╪═════════╪═════════╡
# │ Москва    ┆ Москва    ┆ Apple      ┆ iPhone X   ┆ ... ┆ 1         ┆ 303     ┆ 1627171 ┆ 2       │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 2000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Москва    ┆ Москва    ┆ Apple      ┆ iPhone X   ┆ ... ┆ 1         ┆ 303     ┆ 1625011 ┆ 2       │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 2000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Москва    ┆ Москва    ┆ Apple      ┆ iPhone X   ┆ ... ┆ 1         ┆ 303     ┆ 1625356 ┆ 2       │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 8000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Москва    ┆ Москва    ┆ Apple      ┆ iPhone X   ┆ ... ┆ 1         ┆ 303     ┆ 1625270 ┆ 2       │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 4000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ ...       ┆ ...       ┆ ...        ┆ ...        ┆ ... ┆ ...       ┆ ...     ┆ ...     ┆ ...     │
# │ Кировская ┆ Киров     ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 2         ┆ 414588  ┆ 1625184 ┆ 3       │
# │ область   ┆           ┆            ┆ 8 Pro      ┆     ┆           ┆         ┆ 0000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Кировская ┆ Киров     ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 1         ┆ 414588  ┆ 1625702 ┆ 3       │
# │ область   ┆           ┆            ┆ 8 Pro      ┆     ┆           ┆         ┆ 4000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Кировская ┆ Киров     ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 5         ┆ 414588  ┆ 1626652 ┆ 3       │
# │ область   ┆           ┆            ┆ 8 Pro      ┆     ┆           ┆         ┆ 8000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# │ Кировская ┆ Киров     ┆ Xiaomi     ┆ Redmi Note ┆ ... ┆ 3         ┆ 414588  ┆ 1627084 ┆ 3       │
# │ область   ┆           ┆            ┆ 8 Pro      ┆     ┆           ┆         ┆ 8000000 ┆         │
# │           ┆           ┆            ┆            ┆     ┆           ┆         ┆ 00      ┆         │
# └───────────┴───────────┴────────────┴────────────┴─────┴───────────┴─────────┴─────────┴─────────┘

# %%
q2 = q.sort("timestamp").groupby("user_id").agg([pl.col("timestamp"), pl.col("price"), pl.col("cpe_model_name").unique()])
q2
# Out:
# shape: (964, 4)
# ┌─────────┬────────────────────┬─────────────────────────────────────┬─────────────────────┐
# │ user_id ┆ timestamp          ┆ price                               ┆ cpe_model_name      │
# │ ---     ┆ ---                ┆ ---                                 ┆ ---                 │
# │ i32     ┆ list[i64]          ┆ list[f32]                           ┆ list[str]           │
# ╞═════════╪════════════════════╪═════════════════════════════════════╪═════════════════════╡
# │ 350064  ┆ [1623801600000000, ┆ [14990.0, 14990.0, ... 17490.0]     ┆ ["Galaxy M21"]      │
# │         ┆ 1623801600000...   ┆                                     ┆                     │
# │ 350696  ┆ [1627948800000000, ┆ [12993.0, 9490.0, ... 9490.0]       ┆ ["Galaxy A20 Dual"] │
# │         ┆ 1629158400000...   ┆                                     ┆                     │
# │ 104728  ┆ [1649721600000000, ┆ [163626.0, 163626.0, ... 137768.... ┆ ["iPhone 13 Pro"]   │
# │         ┆ 1649721600000...   ┆                                     ┆                     │
# │ 340800  ┆ [1623801600000000, ┆ [20712.0, 20712.0, ... 11133.0]     ┆ ["Galaxy A50 Dual"] │
# │         ┆ 1623801600000...   ┆                                     ┆                     │
# │ ...     ┆ ...                ┆ ...                                 ┆ ...                 │
# │ 175609  ┆ [1623801600000000, ┆ [63016.0, 63016.0, ... 48947.0]     ┆ ["iPhone 11"]       │
# │         ┆ 1623801600000...   ┆                                     ┆                     │
# │ 165545  ┆ [1623801600000000, ┆ [18058.0, 18058.0, ... 15990.0]     ┆ ["iPhone 6"]        │
# │         ┆ 1623801600000...   ┆                                     ┆                     │
# │ 196801  ┆ [1650412800000000, ┆ [22648.0, 22648.0, ... 22773.0]     ┆ ["Redmi Note 10S"]  │
# │         ┆ 1650412800000...   ┆                                     ┆                     │
# │ 141953  ┆ [1623801600000000, ┆ [28325.0, 28325.0, ... 26990.0]     ┆ ["iPhone 7"]        │
# │         ┆ 1623801600000...   ┆                                     ┆                     │
# └─────────┴────────────────────┴─────────────────────────────────────┴─────────────────────┘

# %%
user_sample = q2.filter(pl.col("user_id") == 413913)
user_sample
# Out:
# shape: (1, 4)
# ┌─────────┬─────────────────────────────────────┬─────────────────────────────────┬────────────────┐
# │ user_id ┆ timestamp                           ┆ price                           ┆ cpe_model_name │
# │ ---     ┆ ---                                 ┆ ---                             ┆ ---            │
# │ i32     ┆ list[i64]                           ┆ list[f32]                       ┆ list[str]      │
# ╞═════════╪═════════════════════════════════════╪═════════════════════════════════╪════════════════╡
# │ 413913  ┆ [1624320000000000, 1624320000000... ┆ [13140.0, 13140.0, ... 15516.0] ┆ ["Galaxy A31"] │
# └─────────┴─────────────────────────────────────┴─────────────────────────────────┴────────────────┘

# %%
import matplotlib.pyplot as plt

plt.plot(user_sample["timestamp"][0], user_sample["price"][0])

# %%
import seaborn as sns

sns.distplot(df["price"])
